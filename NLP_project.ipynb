# %% [markdown]
# <a href="https://colab.research.google.com/github/gioferola/AN2DL_challenges/blob/main/NLP_project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import userdata
TOKEN = userdata.get('github_token')
USERNAME = 'gioferola'
REPO_NAME = 'NLP_project'
remote_url = f"https://{TOKEN}@github.com/{USERNAME}/{REPO_NAME}.git"


# !git clone {remote_url}
# Out:
# Cloning into 'NLP_project'...
# ...
